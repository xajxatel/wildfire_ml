# %% [markdown]
# <a href="https://colab.research.google.com/github/AnanyaJain3/ML_Proj/blob/main/Main%20Project/Main_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# preprocessing data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pwd
# Out:
# /content

# %%
df = pd.read_csv("Wildfires.csv")
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# Column Names

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %% [markdown]
# min, max , mean , 1st quartile , 3rd quartile of attributes

# %%
min_values = df.min()
max_values = df.max()
mean_values = df.mean()
first_quartile = df.quantile(0.25)
print("min")
print(min_values)
print("max")
print(min_values)
print("mean")
print(min_values)
print("first quartile")
print(min_values)
# Out:
# min
# X           1
# Y           2
# month     apr
# day       fri
# FFMC     18.7
# DMC       1.1
# DC        7.9
# ISI       0.0
# temp      2.2
# RH         15
# wind      0.4
# rain      0.0
# area      0.0
# dtype: object
# max
# X           1
# Y           2
# month     apr
# day       fri
# FFMC     18.7
# DMC       1.1
# DC        7.9
# ISI       0.0
# temp      2.2
# RH         15
# wind      0.4
# rain      0.0
# area      0.0
# dtype: object
# mean
# X           1
# Y           2
# month     apr
# day       fri
# FFMC     18.7
# DMC       1.1
# DC        7.9
# ISI       0.0
# temp      2.2
# RH         15
# wind      0.4
# rain      0.0
# area      0.0
# dtype: object
# first quartile
# X           1
# Y           2
# month     apr
# day       fri
# FFMC     18.7
# DMC       1.1
# DC        7.9
# ISI       0.0
# temp      2.2
# RH         15
# wind      0.4
# rain      0.0
# area      0.0
# dtype: object
# ...

# %%
df.columns = [column.lower() for column in df.columns]
print(df)
# Out:
#      x  y month  day  ffmc    dmc     dc   isi  temp  rh  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]
